# %% [markdown]
# # Sales Performance Analysis Project

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('superstore_sales_dataset.csv')
df.head()
# Out:
#    Order Date Region         Category Product Name  Sales  Profit  Quantity
# 0  2022-01-01   East       Technology       Binder   1538     906         7
# 1  2022-01-02  South  Office Supplies        Chair    838    -130         9
# 2  2022-01-03   West  Office Supplies        Chair   4615     190         8
# 3  2022-01-04   East  Office Supplies       Binder   3390    1343         6
# 4  2022-01-05  South       Technology        Phone   2075     782         2

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    200 non-null    datetime64[ns]
#  1   Region        200 non-null    object
#  2   Category      200 non-null    object
#  3   Product Name  200 non-null    object
#  4   Sales         200 non-null    int64
#  5   Profit        200 non-null    int64
#  6   Quantity      200 non-null    int64
#  7   Month         200 non-null    int32
# dtypes: datetime64[ns](1), int32(1), int64(3), object(3)
# memory usage: 11.8+ KB
#                 Order Date        Sales       Profit    Quantity       Month
# count                  200   200.000000   200.000000  200.000000  200.000000
# mean   2022-04-10 12:00:00  2542.305000   464.420000    4.915000    3.840000
# min    2022-01-01 00:00:00   100.000000  -493.000000    1.000000    1.000000
# 25%    2022-02-19 18:00:00  1274.750000   -55.500000    3.000000    2.000000
# 50%    2022-04-10 12:00:00  2579.000000   406.500000    5.000000    4.000000
# 75%    2022-05-30 06:00:00  3777.000000  1003.500000    7.000000    5.000000
# max    2022-07-19 00:00:00  4976.000000  1477.000000    9.000000    7.000000
# std                    NaN  1450.464861   584.367969    2.551534    1.926906

# %%
df.isnull().sum()
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
total_sales = df['Sales'].sum()
print('Total Sales:', total_sales)
# Out:
# Total Sales: 508461

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False)
print(top_products.head())
# Out:
# Product Name
# Phone      108273
# Table      105917
# Chair       82452
# Binder      74771
# Printer     74122
# Name: Sales, dtype: int64

# %%
df['Month'] = df['Order Date'].dt.month
monthly_sales = df.groupby('Month')['Sales'].sum()
monthly_sales.plot()
plt.show()
